# %% [markdown]
# # Translation of the french category names to english

# %% [markdown]
# ### Read the given category names csv file using pandas

# %%
import pandas as pd
df=pd.read_csv('category_names.csv')
df.head()
# Out:
#    category_id              category_level1     category_level2  \
# 0   1000021794        ABONNEMENT / SERVICES      CARTE PREPAYEE
# 1   1000012764  AMENAGEMENT URBAIN - VOIRIE  AMENAGEMENT URBAIN
# 2   1000012776  AMENAGEMENT URBAIN - VOIRIE  AMENAGEMENT URBAIN
# 3   1000012768  AMENAGEMENT URBAIN - VOIRIE  AMENAGEMENT URBAIN
# 4   1000012755  AMENAGEMENT URBAIN - VOIRIE        SIGNALETIQUE
#
#                    category_level3
# 0        CARTE PREPAYEE MULTIMEDIA
# 1                      ABRI FUMEUR
# 2            ABRI VELO - ABRI MOTO
# 3                   FONTAINE A EAU
# 4  PANNEAU D'INFORMATION EXTERIEUR

# %%
df.shape
# Out:
# (5270, 4)

# %% [markdown]
# * There are 5270 unique categories of products.
# * The csv file maps the given category id to the category levels given in the csv file

# %% [markdown]
# ### Let us check if the given category id corresponds directly to category level 3

# %%
df['category_level3'].shape
# Out:
# (5270,)

# %% [markdown]
# * Yes the given category id directly corresponds to the category level 3

# %% [markdown]
# ## Here we wil translate the columns one by one using googletranslate module which is fairly accurate as we have to translate only a set of 2 or 3 words and not long sentences etc

# %% [markdown]
# ### <b> 1. Translating category_level3 column

# %%
from googletrans import Translator

translator = Translator()

#store all the category names in an array
arr=list(df['category_level3'].values)

#strip the names so that spaces are removed at the ends which is causing problem when translating
arr2= [var.strip() for var in arr]

#list to store the translated category names 
translated_sent=[]

#Loop through each category name to translate it and save it to the list
from tqdm import tqdm
for sent in tqdm(arr2):
    arr2_trans=translator.translate(sent,src='fr',dest='en')
    translated_sent.append(arr2_trans)
# Out:
# 100%|██████████| 5270/5270 [1:58:17<00:00,  1.35s/it]

# %% [markdown]
# ### Here we have saved the googletranslate object and not the actual text , so we need to get the translated text from it as shown below

# %%
translated_category = [sent.text for sent in translated_sent]
translated_category
# Out:
# ['PREPAYEE MULTIMEDIA CARD',
#  'Smoking shelter',
#  'Bike shelter - motorcycle shelter',
#  'WATER FOUNTAIN',
#  'Exterior Information Panel',
#  'Signaling Cone - Signage Plot',
#  'ROAD PANNEL',
#  'Signaling ribbon',
#  'Parking Block - Parking Cop',
#  'Post - Post',
#  'Trough',
#  'Taper',
#  'FEEDING BOTTLE',
#  'Food distributor',
#  'WATER FOUNTAIN',
#  'Gamelle - ECUEL - Gamelle accessory - ECUEL ACCESSORY',
#  'Accessory kit for meals',
#  'Featoire - Tremie',
#  'Nourishing Clip - Nourishing Excavator - Nourishing Spoon',
#  'RACK',
#  'Food Transport - Storage Box - Candy Pouch',
#  'Food Mineral - Shell - Salt in Lecher - Pierre To Breed',
#  'Farm Food - Food Compressor',
#  'Power Box - Food Patee - Wet Food - Soft Food',
#  'GREASE BALL',
#  'Croquette - Dry Food',
#  'Extrude - granule',
#  'Flakes - Mash - Muesli',
#  'Hay - Fodder',
#  'Fondness',
#  'SEEDS',
#  'Eating Grass - Cat Grass',
#  'Animal feed kit',
#  'MEDIUM MEDIUM - Drink Maternal',
#  'Catiere - Cat Door - Cat Trap',
#  'HEATER',
#  'LIGHTING',
#  'Maintenance - Treatment',
#  'Air Filter - Water Filter',
#  'Kit Habitat Technical Development',
#  'Air Pump - Air Diffuser -',
#  'Thermometer - Hydrometer',
#  'Saddle accessory',
#  'Bride - Bridon - Muserolle - Cavecon',
#  'NECKLACE',
#  'Animal harness',
#  'Kit Attachment - Saddle Kit',
#  'Leave - Strap - Scattered - Strap Sheath',
#  'Longe - Licol',
#  'Mors - Mouth',
#  'MUZZLE',
#  'REINS',
#  'SADDLE',
#  'Artificial Decoration - Decor Background',
#  'Habitat Decoration Kit',
#  'Pearl - Glass Ball - Gravel - Rock - Pierre for Aquarium - Terrarium - Vivarium',
#  'Aquarium plant - Vivarium - Terrarium - Vegetable Decoration - Substrate - Racine - Wood',
#  'Dressage Rod - Dressage Necklace',
#  'Hunting - Tracking - Reperage',
#  'Clicker - Whistle - Disc - Bipper',
#  'Anti-barking necklace - Anti-barking device',
#  'Anti-Fugue Necklace - Anti-Fugue Cloture - Anti Fugue Pack',
#  'Kit Education Activity',
#  'Training Material - Material Agility',
#  'Fastener',
#  'Repulsive - Attractive',
#  'Cage accessory - Small animal shelter',
#  'AQUARIUM',
#  'Animal basin',
#  'CAGE',
#  'HUTCH',
#  'Recycle Basket - Cushion - Hammock',
#  'Coverage - Plaid',
#  'Cage Cage - Perchor Covers',
#  'Enclosures - kennel',
#  'Habitat Kit - Sleeping',
#  'NICHE',
#  'Nest - nest',
#  'PARK',
#  'PERCH',
#  'CHICKEN COOP',
#  'Under furniture - foot for aquarium - terrarium - vivarium',
#  'Vivarium - Terrarium',
#  'Vole - Bird Cage',
#  'Tray a litter',
#  'Desodorizer - Litial Cleaner',
#  'HYGIENE KIT LITIERE DEJECTIONS',
#  'Mineral Library - Silica Listing - Clail Liece',
#  'VEGETAL LITIER - STRAILLE A LIX - HEMP LITIER - LITIER CHIPS - FLONCONE LITIER - LITIERE but',
#  'Toilette - Bac a Liere - Charcoal Filter - Towel Carpet - Littery Carpet',
#  'Shovel A litter - fork a litter',
#  'Littery trash',
#  'Litter bag',
#  'Clean Bag - Pick up Drunk - Dejection - Excrements',
#  'On-liter - cage background',
#  'Cleancores - Apprenticeship - Alese',
#  'Playground - Game Pad - Game Tunnel',
#  'CAT TREE',
#  'SWING',
#  'Ball - Frisbee',
#  'Animal game rope',
#  'Scratch - Scraper - Tour - Post - Trunk',
#  'TOY',
#  'Toy with a treat',
#  'Toy Kit - Set Toy Set',
#  'STUFFED TOY',
#  'Pont - Staircase',
#  'Rodent Exercise Wheel - Rodent Exercise Ball',
#  'Grooming bathtub',
#  'Brush - Brushing Glove - Card',
#  'Scissors - knot cutters',
#  'Nail Cup - Claws',
#  'Foot Cure - Scraper - Repene',
#  'Staggering',
#  'Grooming Material Kit - Doldering',
#  'Lime - Rappe - Brush',
#  'Comb - DEMOELOLE',
#  'Sechoir - Pulse',
#  'Towel - bathrobe',
#  'Grooming table',
#  'Animal mower',
#  'Incubator incubator',
#  'Kit Maternage - Breeding',
#  'Feather',
#  'POWER - Breeding tray',
#  'Collete - convalescence necklace',
#  'DIETARY SUPPLEMENT',
#  'Hygienic Panties - Layer - Incontinence - Menstrual Protection - Chaleurs',
#  'Well-Being Diffuser - Soothing Spray - Spray Anti-Stress - Anti Nervosite Spray',
#  'Care Product Kit - Hygiene',
#  'Animal cleansing wipe',
#  'Perfume - Desodorizer - Designant',
#  'Pest Management Pipette - Anti-PARASITIES COLLAR - SPRAY SPRAYSITARY - Crochet ticks - Antipipart Shampoo',
#  'Shampoo - After Shampoo - Conditioner - Mask',
#  'Special care',
#  'Land A bath - Sand in bath',
#  'Security Barrier Stairway - SECURITY BARRIER door',
#  'Protective net - Protection grid',
#  'Rescue Vest - Security Vest',
#  'SECURITY KIT - PROTECTION',
#  'Identification Medal - Identification Pendant - Identification Ring',
#  'Guard Plate - Auto Signacetics',
#  'Reflector - Necklace lamp',
#  'Handling Accessory - Glove - Crochet - Pliers - Edge',
#  'Transportation Fund - Transportation Cage',
#  'SEATBELT',
#  'Transportation Kit - Move - Walk',
#  'Transport basket - transport bag',
#  'Animal stroller',
#  'Carpet',
#  'Bandana - Scarf - Tie - Scarf - Butterfly knot',
#  'JEWEL',
#  'Cap - Bonnet - Hat - Ear Protege - Snood',
#  'SHIRT',
#  'Costume - Together',
#  'Rein Covers - Shoulder Covers',
#  'CHEEKY',
#  'DISGUISE',
#  'Clothing Kit - Accessory',
#  'EYEGLASSES',
#  'COAT',
#  'Nodes - Barrettes - Elastics',
#  'Pants - Pajama',
#  'Protection of legs - Shoes - Socks',
#  'Sweater - Vest',
#  'DRESS SKIRT',
#  'Bag - Animal bag',
#  'T-Shirt - Body - Top',
#  'Bee Hunting - Insect Trap - Piece Cap',
#  'Tray Range Covered - Cutlery Tray for Drawer',
#  'Stick',
#  'Cache kitchen plate',
#  'Top Paper Devidoir - Support Wiper',
#  'Induction relay disc - Induction relay plate',
#  'Dispenser',
#  'Cutlery spindle',
#  'Closet shelf - Closet basket - cupboard basket',
#  'Pin - Accessory Cleaning Carafe - Accessory Cleaning Bottle',
#  'Sink grill',
#  'Anti-projection plate - Anti-projection screen',
#  'Manual drink pump',
#  'Sauce',
#  'Sponge Porte - Soap Door',
#  'Cutlery Pot - Range Utensils',
#  'Range Plate - Separator plate',
#  'Bottle Range (Non Furniture) - Carpet Range Bottle',
#  'Glass Range - Glass Holder - Glass Rack',
#  'Bag Bag - Storage Plastic Bags',
#  'Separator - Protege Poele - Separate Pan - Prostege Pan',
#  'Kitchen accessory set',
#  'Popor Magnetic - Magnetic Storage',
#  'Kitchen Book Support - Kitchen Lutrin',
#  'Rug',
#  'Drawer mat',
#  'Suction cup - hook - wall hanging',
#  'Food Tray - Food Case',
#  'Conservation jars',
#  'Bread box - bread bag',
#  'Conservation boxes - Hermetic boxes',
#  'Isothermal Bottle - Insulating Bottle',
#  'Universal lid - LICE COVER',
#  'Food label',
#  'Food Movie - Aluminum Film',
#  'Glaciere - Isothermal bag - Cold Accumulator',
#  'Close Clip bag - Clip Farm bag',
#  'Conservation bag - vegetable bag',
#  'VACUUM SYSTEM',
#  'Accessories for pressure cookers',
#  'Pressure cooker - Minute casserole',
#  'Jam Ragout Basin',
#  'COOKWARE',
#  'Pin - Skewer',
#  'PAN',
#  'Cassolette - Poeel - Caqueon - Devil - Terrine',
#  'Cocotte',
#  'Coussecker',
#  'Lid sold alone',
#  'Rice cooker - Pate cooker',
#  'Cooked Egg - Egg Pocket',
#  'STEAMED',
#  'Delivery - Marmite',
#  'Cooking Sheet - Oven Mat - Cooking Canvas',
#  'DEEP FRYER',
#  'Grill - Crepiere',
#  'Grid - Anti-projection lid',
#  'Poke',
#  'Cooking basket - cooking net',
#  'Cooking spare parts',
#  'Oven Plate - Four Grid',
#  'Paella dish',
#  'Oven dish',
#  'Poele - Scenery',
#  'Cooking bag - Steam bag',
#  'TAJINE',
#  'Wok',
#  'Sharpener - Affifier - Accessory Sharpeting',
#  'Kitchen Scissors - Herbal Scissors',
#  'Foie Gras Cup - TERRINE CUTTING - Butter yarn',
#  'Fruit Cup - Fruit Cut - Fruit Slicer',
#  'KITCHEN KNIFE',
#  'Cutout',
#  'Kitchen Fork - Meat Forchet',
#  'Manual chopper',
#  'Mandolin - Elimmer - Food cutter',
#  'CUTTING BOARD',
#  'Knife Protection - Knife Case - Knife Briefcase - Knife Block',
#  'Fingerprint',
#  'SCRAPER',
#  'Butcher saw - Butcher saw blade',
#  'Lunch Box - Meal Box',
#  'Picnic basket',
#  'Picnic Carpet - Picnic Cover',
#  'Anti-drop - spout',
#  'Glacony Bac - Glacon Bag',
#  'Skinny',
#  'Bottle cap - metering cap',
#  'Carafe to Decanter - Wine carafe - wine aerator',
#  'Degustation Sock - Bottle Cover',
#  'Sommelier box - Oenology box',
#  'Carafe Grassroot',
#  'Fake glacons',
#  'Flaccid',
#  'Alcohol Fountain - Wine Fountain',
#  'Non-disposable straw',
#  'Non-disposable aperitative peaks',
#  'Wine Pump - WINE CONSERVATION PUMP',
#  'Bottle holder - Vourage System',
#  'Wine cubic bag',
#  'Glacon bucket - refreshment',
#  'Shaker - Agitator - Set Cocktail',
#  'THERMOMETER WINE',
#  'Stopper - Decapsulur - Limonadier',
#  'PLATE',
#  'Baguette - Set for Asian cuisine',
#  'Butter - Hiller - Vinearrier',
#  'Service bell',
#  'Crock',
#  'Recycle Basket',
#  'Ice cup - Ice cut',
#  'Table knife',
#  'Tablespoon',
#  'Flat - Flat holder',
#  'Glass underneath - bottom of bottle',
#  'Candle Dispenser - Cereal Distributor',
#  'Towels distributor - Napkin holder',
#  'Table range',
#  'Brand-Place - Name Holder',
#  'Menager - Full Cutlery Service',
#  'Pitcher - Carafe - Service Bottle',
#  'Pique A but',
#  'Tray - Service Flat',
#  'Cheese Tray - Cheese Bell',
#  'Level Tray - Presentation Tray A Floor',
#  'Fruit Door - Fruit Cup',
#  'Toast holder',
#  'Table trash can',
#  'Crumbs',
#  'Ramequin - Ravier - Shell',
#  'Rest covered',
#  'NAPKIN RING',
#  'BOWL',
#  'SEL - Pepper - Mustard',
#  'Fondue service',
#  'Seafood service',
#  'Full Service - Table Service',
#  'Soupted - Sauciere',
#  'Subset',
#  'Glass A Biere - Mug A Biere - BOLEE A CIDRE',
#  'Champagne Glass - Champagne Cup - Champagne Flute',
#  'Cocktail Glass - Glass Aperitif',
#  'Glass Digestive - Shooter',
#  'Water Glass With or Foot Free - Syrup Glass - Fruit Juice Glass - A Soda Glass - Goblet',
#  'Wine Glass - Glass A Dustation',
#  'Glasses In Assortment - Melange of Glasses',
#  'Verrine - Missing',
#  'Sugar box - sugar',
#  'Bowl - Mug - Mazagran',
#  'Traditional kettle - whistle',
#  'CAFETIERE - Theiere - Chocolatiere',
#  'Cremier',
#  'Cafe Capsules Dispenser - Capsule Dispenser',
#  'Infuser - Colander at the',
#  'Repository bag of the',
#  'Sprinkler - sugar pouring - cocoa pouring',
#  'Cafe Service - Service A The',
#  'Pate machine accessory',
#  'Gas Lighter - Fire Light',
#  'Device to stuff - Needle to Brider',
#  'Tender - meat drummer',
#  'Butter baratte',
#  'Ceramic Ball - Chain Tart Background',
#  'Rice Ball - Spice Ball',
#  'Dietary brush',
#  'Nutcracker - Nutcracker',
#  'DISH WARMER',
#  'Fish cutter',
#  'ECONOME - Peel - Peel - Zester - roller',
#  'SKIMMER',
#  'Utensils set - lot utensils',
#  'FUNNEL',
#  'Epepineuse',
#  'Crank Peel - Crank Peel',
#  'Evideur - Liner',
#  'Cooking string - cooking elastic',
#  'Manual Whisk - Magic Spoon',
#  'Maki Sushi Kit - Asian Kit',
#  'Lady - Cooking Spoon',
#  'Pate machine',
#  'Vinaigrette MELINDER',
#  'Mortar - Pilon - Manual Crusher',
#  'Cooking mill',
#  'Frying nest',
#  'Boite Open - Jars',
#  'Basket with salad - wrinkler',
#  'Colander - Chinese',
#  'Service pliers',
#  'Cook brush',
#  'Pear with juice - pear with sauce',
#  'Spice',
#  'Sausage pusher',
#  'Press Puree - Moulin A Legume',
#  'Fruit Press - Press Legume - Manual Citrust Presse',
#  'GRATED',
#  'Repository Utensils',
#  'Egg Separator - Egg Topper',
#  'Siphon - Cartridge for Siphon',
#  'Manual sorbette',
#  'Spatula - Maryse - Rateau a Crepe',
#  'Ham support',
#  'Analog scale',
#  'Timer - hourglass',
#  'Messary Pipette - PESE SIROP',
#  'Kitchen Thermometer - Probe - Cooking Tester',
#  'Dosing Glass - Meter - Spooner - Kitchen Top',
#  'Banneton - Manna',
#  'Baton for Gateau Pacifier - Patisserie Batonnet - Baton Pop Cake',
#  'Bowl Mixer - Bowl Preparation',
#  'Tempered Brooch - Tempered Fork',
#  'Patisser',
#  'Caispet - Paper Mold',
#  'Patisserie torch',
#  'Doupair - Piece cookie',
#  'Divisor - Cake Cut',
#  'Eburseoir - Incisette Blade - Bread Footprint',
#  'Patisserie',
#  'Patisserie',
#  'DRYING GRID - RELAIE',
#  'Patisserie Guitar',
#  'Churros Machine - Chichi',
#  'Gateau Mold - Patisserie Mold',
#  'Shovel - Pellon - Palette - Horn',
#  'BAKING SHEET',
#  'Socket Pocket - Pistol - Syringe',
#  'Raclette - Patch cutter',
#  'Scroll roller - roll roller',
#  'Support - bearing for pacifier cake - Pop Cake presentation',
#  'Decoration utensils',
#  'Disposable plate',
#  'Disposable cutlery',
#  'TOOTHPICK',
#  'Straw - Touveleur - Disposable Touillette',
#  'Cocktail Picks - Peaks Aperoo',
#  'Flat - Disposable Tray',
#  'Disposable tableset',
#  'Disposable Glass - Disposable Gobble',
#  'Disposable verrine',
#  'Charcoal',
#  'Chicha - Narguile',
#  'MAINTENANCE OF CHISHA',
#  'Aluminum Sheet for Chicha',
#  'Filter for Chicha - Filter tip for shisha',
#  'Chicha fireplace',
#  'Coal clip',
#  'Chicha tobacco pot',
#  'Chicha pipes',
#  'Vase in chicha',
#  'Cigar cellar',
#  'Cigar cut',
#  'Cigar case',
#  'Cigar humidifier',
#  'Tobacco Box - Tobacco Joke',
#  'Lighter - Cigar lighter',
#  'ASHTRAY',
#  'Cigarette case',
#  'Rolling Sheet - Blunt',
#  'Cigarette filter',
#  'Smoke cigarette',
#  'Tobacco Humidifier - Tobacco Flavor',
#  'Rolling machine',
#  'Tuber machine',
#  'Cigarette tube',
#  'Electronic cigarette battery',
#  'Electronic cigarette charger',
#  'Chicha Electronics',
#  'Electronic Cigar - Electronics Cigarillo',
#  'ELECTRONIC CIGARETTE',
#  'Disposable electronic cigarette',
#  'Transport case',
#  'Electronic cigarette liquid',
#  'Electronic Cigarette Pack',
#  'ELECTRONIC CIGARETTE DETACHEE PIECE',
#  'ELECTRONIC PIPE',
#  'Electronic Cigarette Sprayer - Electronic Cigarette Atomizer',
#  'Electronic cigarette recharge',
#  'Electronic Cigarette Support- Electronic Cigarette Neck Tour',
#  'Bourre-Pipe - Pipe Cure',
#  'Pipe filter',
#  'Cleaning Pipe - Pipe Maintenance',
#  'SMOKING PIPE',
#  'Blowjob',
#  'Vaporizer accessory',
#  'VAPORIZER PACK',
#  'Salon spray',
#  'Portable vaporizer',
#  'Airbag',
#  'Alarm - alarm simulator - hyperfreeference module',
#  'Anti-Theft - Wheel Block',
#  'Black Box Video - Embarked Camera',
#  'BREAK - ASSEMBLY - PLATE OF DESLISHMENT',
#  'Belt - Belt System',
#  'Crash Pad',
#  'Signal disk - other signaling adhesive',
#  'Ethylotest',
#  'Caravan mirror extension',
#  'EXTINGUISHER',
#  'Signs',
#  'SAFETY VET - SECURITY KIT - SECURITY TRIANGLE',
#  'Gyrophare',
#  'Windshield speed display kit',
#  'Automatic lighting kit',
#  'SECURITY MIRROR',
#  'License plate - License plate holder',
#  'Door vignette insurance',
#  'Garage protection',
#  'Reversing radar - recoil camera',
#  'Anti-game whistle',
#  'Gyrophare support',
#  'Glaciere Auto - Motorcycle Glaciere - Glaciere Boat',
#  'Fixing kit',
#  'Siege Organizer - Storage Pocket',
#  'Storage Storage - Cargo Strap - Hooks',
#  'Safe Safety Bag - Safe Organizer - Auto Safe',
#  'TRANSPORT BAG',
#  'Sag - Cavaliere - Motorcycle Backpack',
#  'Reservoir rug - Terry bag',
#  'Top box',
#  'Armrests',
#  'Transfer Help - Rotary Cushion - Handybar Handle',
#  'Cigarette lighter - cigarette lighter socket',
#  'ANTENNA',
#  'HEAD SUPPORT',
#  'Support Bar - Head Support - Clothing Holder',
#  'Bubble - Windshield - Wind Saute',
#  'Back Back - Headrest',
#  'Ongleless Headphones - Active Exhaust',
#  'Side heating for vehicle',
#  'Car converter',
#  'VEHICLE PROTECTION COVER - VEHICLE BABY',
#  'Steering wheel',
#  'Pedal covers',
#  'Auto Desodorizer - Auto Perfume',
#  'Hubcap',
#  'Belt sheath',
#  'Handlebar - Handlebar',
#  'Siege cover - seat covers',
#  'Intercom - Communication Kit',
#  'Rims',
#  'AutoRadio Installation Kit',
#  'Lever - Pommels',
#  'Portiere Latch',
#  '2 Wheel Sleeve - Apron for 2 Wheels - Skirt for 2 Wheels',
#  'COMFORT PRODUCT PACK',
#  'Dogwheel - Grid Separation Animals',
#  'Sunspare - Solar Strip - Solar Film',
#  'Pedalier - Brake Pedal',
#  'Vehicle Customization - Vehicle Decoration',
#  'Heaters',
#  'Beverage Door - Beverage Regulator',
#  'CD-DVD-Blu-ray door',
#  'Object Holder - Goggles Holder',
#  'Bin',
#  'External protection',
#  'Rise Leg',
#  'Motorcycle saddle',
#  'Car door threshold',
#  'Siege - Header for Siege',
#  'GROUND SHEET',
#  'Belt',
#  'Extraction fan',
#  'FLYING',
#  'Insulating Component - Protective Component',
#  'Helmet Accessory - Headphone Decoration - Customization Headphone',
#  'Airbag Jacket - Airbag Jacket - Airbag Gest',
#  'Cagoule - Cache-Nez - Neck Tour',
#  'Scooter motorcycle helmet',
#  'Shoe - boot - on-shoe',
#  'COMBINATION',
#  'Dorsal Motorcycle - Motorcycle Belt',
#  'Gloves - Subgants',
#  'Kenouree - Couliere - Jambiere',
#  'Helmet cover',
#  'Driving glasses - driving mask',
#  'Pack',
#  'Pilot protection pack',
#  'Pants - on-pants - Short',
#  'Stone Parent - Bodystunt - Plastron',
#  'Helmet spare part',
#  'PROTECT SELECTOR - INSIDE SOLE - EXTERNAL SOLE',
#  'Slider Jacket - Slider Combination - Slider Pants - Other Sliders',
#  'Pilotage underwear',
#  'Cervical Support - NECK Brace - MINERVE',
#  'Wheel pass box',
#  'ESTABLISHED',
#  'Gutter - Tube Holder',
#  'KIT AERATION - Playing free',
#  'INTERIOR AMENDING KIT',
#  'INTERIOR DRESSING KIT',
#  'Lanternals - Panoramic Roof',
#  'SIDEBAR',
#  'FLOOR',
#  'Automatic Water Pump - Manual Water Pump',
#  'Service Door - SERVICE GOUND - Safe Chest Gate Door',
#  'Connection RESERVOIR - Cap',
#  'Storage - Locker - Sheaper',
#  'Reservoir Water USES - TENERVOIR EATED WATER - RESERVOIR',
#  'Performance Additive - Maintenance - Cleaning - Anti-Smoke',
#  'Auto vacuum',
#  'Balm - embellisor - polish - wax - lustrur',
#  'Anti-crevison bomb',
#  'Brush - Raclette',
#  'Grease cartridge',
#  'Cleaning box',
#  'Lustration Cotton - Lustration Equipment',
#  'DEGRIPANT - Lubricant',
#  'Clear scratch - renovator',
#  'Sponge - Chamois Skin - Microfiber - Cloth',
#  'Auto gloves',
#  'Engine oil',
#  'Transmission oil',
#  'Auto wipe',
#  'Fork Liquid - Fork Oil',
#  'BRAKE FLUID',
#  'COOLING LIQUID',
#  'WINDSHIELD WASHER FLUID',
#  'Lustrous - Polisheuse',
#  'Brake cleaner',
#  'Exterior engine cleaner',
#  'Window cleaner',
#  'Cleaning Pate - Cleaning Solvent - Repair Pate - Repair Solvent',
#  'Car paint',
#  'Wash pistol',
#  'Snow Raclette - Degree',
#  'Exterior Cleaning Shampoo - Outdoor Cleaner Product',
#  'Interior Cleaning Shampoo - Interior Cleaner Product',
#  'Drain tray',
#  'Broom - Car Raclette',
#  'Flying Flying Engine - Block PIGNA - Engine Distribution Timing Set',
#  'Battery Booster - Start Station',
#  'Oil burette',
#  'Start Cable - Overvoltage Enter',
#  'CANDLE',
#  'BATTERY CHARGER',
#  'Garage carriage',
#  'CLOW',
#  'Clergy',
#  'Central clutch adapter box',
#  'Toolbox',
#  "Mechanic's combination",
#  'Car compressor',
#  'Spring Compressor - Demonte Shock Absorber',
#  'Pressure controller',
#  'Earns - Son',
#  'BATTERY SWITCH',
#  'JACK',
#  'Cut - Decolle Windshield',
#  'TIRE LEVER',
#  'Derive chain',
#  'Voltage detector',
#  'Magnetic finger',
#  'Sockets - tips',
#  'Lighting workshop',
#  'Drain funnel',
#  'Bubber',
#  'Extractors - Rolling Deleting - Rotube Trunk',
#  'Cleaning fountain',
#  'PROTECTIVE GLOVES',
#  'Workshop Crane - Hydraulic Chevre',
#  'Jerrican for auto-motorcycle liquid',
#  'Deboseling kit',
#  'Enhancement Kit - Building',
#  'Renovation Kit Valve',
#  'Engine drain kit',
#  'Bodywork Verin Kit',
#  'Leve-motorcycle',
#  'PROTECTIVE GLASSES',
#  'MANOMETER',
#  "PROTECTION'S MASK",
#  'Pompist Equipment',
#  'Microbilleuse - sandy',
#  'Rim Mount - Wheel Mounting',
#  'Multimeter',
#  'Organization Workshop - Garage Organization',
#  'Diagnostic tool',
#  'Exhaust Pot Tool',
#  'Workshop hoist',
#  'COMPRESSOR PIECE',
#  'Car clip',
#  'Grease pump - grease pump accessory',
#  'Foot pump',
#  'Automotive vacuum pump',
#  'Workshop bridge',
#  'HURRY',
#  'Brake Trap - Brake Purge Kit',
#  'Repeat brake piston',
#  'Oil syringe',
#  'Distribution timing set',
#  'Engine Support - Engine Lifting Tool',
#  'Pneumatic support',
#  'Belt tensioner',
#  'Electrical Tester - Continuity Tester',
#  'Leakage Tracer - Leakage Tracer Kit',
#  'Car winch',
#  'Direct admission',
#  'Dynamic admission',
#  'ALTERNATOR',
#  'Shock Absorber - Amortization Kit',
#  'Bulb - Lighting Scoreboard',
#  'Cam Tree - Distribution Tree',
#  'DRIVE SHAFT',
#  'Etancheite Ring - Spi Seal - Spy Seal - O-ring',
#  'Ice wiper broom',
#  'ANTI RAPPROCHEMENT BAR',
#  'TOWING BAR',
#  'STABILIZING BAR',
#  'Vehicle battery',
#  'Central Bequille - Lateral Bequille',
#  'Rod',
#  'Connect - Coupling bar',
#  'ENGINE BLOCK',
#  'Ignition Coil - High Voltage Coil',
#  'Air box',
#  'Gearbox - Transfer box - Pont - DIFFERENTIAL',
#  'Case - CLE COQUE - REMOTE CONTROL',
#  'Electronic Housing - Additional Case',
#  'BUTTERFLY HOUSING',
#  'Radiator cap',
#  'Oil filler cap',
#  'TANK CAP',
#  'DRAIN PLUG',
#  'Car candle',
#  'Ignition candle',
#  'GLOW PLUG',
#  'Wheel Bolt - Wheel Nut - Wheel Soujon',
#  'Bottle',
#  'Suspension arm - suspension triangle',
#  'CLUTCH THRUST BEARING',
#  'ACCELERATOR CABLE - GAS CABLE',
#  'CLUTCH CABLE',
#  'Hand brake cable',
#  'Capot - Grid - Fire Kit',
#  'ABS sensor',
#  'Acceleration sensor',
#  'Knocking sensor - Knok sensor - rattling sensor',
#  'Fuel Level Sensor - Fuel Level Probe - Fuel Gauge',
#  'Camshaft Tree Position Sensor - PMH Sensor - High Death Sensor - Ignition Pulm Sensor',
#  'TEMPERATURE SENSOR - TEMPERATURE PROBE',
#  'CARBURETOR',
#  'Cardan',
#  "Forkhead Care - Lateral Covers - Radiator's orie",
#  'Crankcase',
#  'CHARGER',
#  'Chassis of Nude Vehicle - Stabilizer',
#  'Piston shirt',
#  'Auto Auto - CLE CLE',
#  'IGNITION KEY',
#  'Moto cocotte',
#  'Admission manifold',
#  'EXHAUST MANIFOLD',
#  'Exhaust necklace',
#  'Battery necklace',
#  'Combine Springs - Suspension Kit - Suspension Cup - Suspension Bale',
#  'SWITCH',
#  'Comodo',
#  'Air conditioning compressor',
#  'Counter - Tower Account',
#  'Air conditioning condenser',
#  'Case - Carenage',
#  'Timing Belt - Distribution Kit',
#  'Trapezoidal belt in ribs - accessory belt - accessory belt kit',
#  'Directional Clear - Steering Cylinder',
#  'CYLINDER HEAD',
#  'Rocker',
#  'Airflower',
#  'STARTER',
#  'AIR CONDITIONER',
#  'Diabolo Moto',
#  'CLUTCH DISC',
#  'Brake discs',
#  'Downpipe',
#  'Inlet Hose - Air Hose',
#  'Cooling hose - Water hose',
#  'Turbo hose - bonding hose - pressure hose',
#  'Exchanger - Intercooler',
#  'Handlebars',
#  'Spacer - Flying Hub',
#  'Brake',
#  'Air conditioning evaporator',
#  'Ignition beam',
#  'Template lights - Close lights',
#  'AIR FILTER',
#  'FUEL FILTER',
#  'Oil filter',
#  'CABIN FILTER',
#  'Brake hose - brake hose - brake hose - Aviation hose',
#  'Fuses',
#  'Tensioner Galet - Belt Tensioner - Damper Pulley',
#  'Chain tensioner roller - Chain tensioner',
#  'Mudguard - Bib',
#  'HANDLEBAR',
#  'Injector - Fuel Injection System - Diesel Injection System',
#  'Auto Brand Badge',
#  'Switch - Actuator - Pulse',
#  'Exhaust gasket',
#  'Cache joint',
#  'Cylinder head gasket',
#  'Transmission seal',
#  'Drain joint',
#  'Body Kit - Cashier - Farm - Spoiler - Becquet - Blade - Parechoc - Callander - wing splarder',
#  'Chain Kit - Chain - Fast Fastening - Crown - Pinion - Transmission Belt',
#  'Clutch kit',
#  'Rear Brake Kit - Brake Machine Kit',
#  'Brake Repair Kit - Brake Refigure Kit',
#  'Repair Kit Mirror',
#  'REVISION KIT',
#  'Screwdriver',
#  'Big brake kit',
#  'HONK',
#  'Glass Leve - Mechanism Glass Leve',
#  'Clutch lever',
#  'Hand brake lever',
#  'Complete Line - Exhaust Line - Exhaust Pot',
#  'BRAKE SHOE',
#  'Maitre-brake cylinder',
#  'Clutch mechanism',
#  'Full engine',
#  'Wiper engine',
#  'Handlebar',
#  'WHEEL HUB',
#  'Bearing - Auto Lander Aligner',
#  'Skill probe - Engine not a step',
#  'Lighthouse eyelid',
#  'PEDAL LATERAL',
#  'Lights - Lights - Lateral Repetition - Flashing - Flashing Central - Rear Fire Block - Lighthouse Optics - PLL Lighting',
#  'Various pieces of exhaust',
#  'PISTON',
#  'Brake pads',
#  'Martio Platinum - Fixing Platinum',
#  'HANDLES - HANDLE OF HANDLE - HEATING HANDLES',
#  'Speed lever knob',
#  'WATER PUMP',
#  'Assisted steering pump',
#  'Baggage Door - Package Door - Sissy Bar',
#  'Hub Door - Fusee Porte',
#  'Car Porterer - Garniture - Interior Coating',
#  'Catalytic Pot - Catalyst',
#  'Alternator pulley',
#  'Protect Frame - Chain - Disc - Fork - Main - Engine - Radiator',
#  'Heating radiator',
#  'Water radiator',
#  'Oil radiator',
#  'Valve extension',
#  'AUTO CIRCUIT RELAY',
#  'Electronic Reparter - Brake Regulator - ABS',
#  'PETROL TANK',
#  'Valve spring',
#  'Suspension spring',
#  'WING MIRROR',
#  'Steering ball',
#  'KNEECAP OF SUSPENSION',
#  'Complete Wheel - Wheel with Rim',
#  'Steering Bearing - Steering Cage',
#  'Wheel Bearing - Wheel Cage',
#  'SERVOFRIN - Pressure accumulator',
#  'Intermediate Silencer - Intermediate Tube',
#  'Silencer for pot - back silencer',
#  'Silentbloc chassis',
#  'SILENTBLOC EXHAUST',
#  'SILENTBLOC SUSPENSION - AXLE SUSPENSION',
#  'SILENTBLOC Engine',
#  'Automotive probe',
#  'LAMBDA PROBE',
#  'BELLOWS GIMBAL',
#  'Bellows',
#  'Suspension bellows',
#  'Transmission bellows',
#  'VALVE',
#  'Admission valve',
#  'Engine block holder',
#  'DASHBOARD',
#  'Brake drum',
#  'Thermostat Water - Thermostat Oil',
#  'SUNROOF',
#  'Turbocharger - Volumetric Compressor - Turbine',
#  'EGR VALVE',
#  'Engine fan',
#  'Van',
#  'Tailgate',
#  'Crankshaft',
#  'Cylinder head screw',
#  'Snow Chain - Sock',
#  'Air chamber for tire',
#  'Tire cover',
#  'Tire Repair Kit - Tire Repair Tool',
#  'Tire Piece - Tire Valve',
#  'Tires',
#  'Towing ring for trailer',
#  'COUPLING',
#  'Trailer learn sold alone',
#  'Towbar - Towing winch',
#  'Roof Bars - Roof Bar Adapter',
#  'COUPLING HOUSING - ROOTTLE HOUSING',
#  'Trailer chassis',
#  'TRUNK',
#  'ROOF BOX',
#  'Trailer connectivity',
#  'Trailer axles',
#  'Trailer Closure - Eccentric Handle',
#  'Trailer fire',
#  'Trailer net',
#  'GALLERY',
#  'Small trailer spare parts',
#  'Kayak holder',
#  'Ski rack',
#  'Velo holder - Velo holder accessories',
#  'Ramp for loading',
#  'Enhance',
#  'TRAILER',
#  'Jockey wheel',
#  'Motorcycle stand',
#  'Trailer Rug - Trailer Stabilizer',
#  'Trailer Roof - Trailer Hood',
#  'Trailer winch - trailer pulley',
#  'Accessories Gyropod - Hoverboard',
#  'CAMPING CAR',
#  'Gyropod',
#  'Hoverboard',
#  'Kart',
#  'MOTORBIKE',
#  'Quad',
#  'ELECTRIC WHEEL',
#  'SCOOTER',
#  'ELECTRIC SKATEBOARD',
#  'ELECTRIC scooter',
#  'CAR',
#  'HOOK BAG',
#  'Alarm',
#  'Luggage padlock',
#  'Suitcase cover - Protection for suitcase',
#  'COMFORT KIT TRAVEL',
#  'Travel mask',
#  'Travel pillow',
#  'Bag Organizer - Bag Pouch',
#  'UMBRELLA',
#  'Pee-luggage',
#  'Multi-bags',
#  'Gateway',
#  'Suitcase',
#  'KEY HOLDER - CLEAN CLEAN',
#  'Housing',
#  'Walking stroller - walking trolley',
#  'Find Key Luggage',
#  'Shoe bag',
#  'Habit bag - Habits transport cover',
#  'Luggage strap',
#  'Travel neck tower',
#  'Manicure Kit - Travel Mercercy Kit',
#  'Travel bag',
#  'Set of travel bags',
#  'Suitcase set',
#  'Suitcase or baggage sold alone',
#  'Computer Cover - Computer Skin',
#  'Luggage Storage Accessories Pack',
#  'Briefcase - Napkin - Case Fastener',
#  'Range CD',
#  'Computer Backpack - Computer Screen Bag - Printer Bag',
#  'Computer Bag - Computer Bag Computer Screen - Printer Bag',
#  'Suitcase - Trolley for Material - Tools',
#  'Computer suitcase',
#  'BANANA',
#  'Bag - Reporter bag',
#  'SATCHEL',
#  'Basket - beach bag',
#  'Hand pouch',
#  'BACKPACK',
#  'Bag to taste',
#  'Swimsuit bag',
#  'HANDBAG',
#  'Bowling bag',
#  'Shopping bag',
#  'Bag',
#  'SPEAKER',
#  'Ticket clip',
#  'CARD HOLDER',
#  'Checker',
#  'WALLET',
#  'Papers',
#  'WALLET',
#  'Everything in one - companion',
#  'Pen kit',
#  'Makeup Kit - Brushes Kit',
#  'Toiletry Kit - Vanity',
#  'Maneuver Bar - Maneuver Stick',
#  'Bimini Top - Taud - Cagnard',
#  'Blocker - Cuckop - CLAM - Filir',
#  'Sectione - Sectional Accessory',
#  'HANDRAIL',
#  'Manila - Emerillon',
#  'Carabiner',
#  'Pitch',
#  'Pulley - Palan - Rea',
#  'TUNER - Axis - ring',
#  'Rotube - Diabolo - Articulation - Maneuvering Base',
#  'Trappe - Hublot - Aeration',
#  'Winch - Crank - Winch Accessories - Ginder',
#  'Inflatable annex',
#  'Boat Cabin Cruiser - Peche Boat - Walk Boat',
#  'PNEUMATIC BOAT',
#  'Reservoir - WC Treatment - Accessory',
#  'Boat car radio - Waterproof speaker',
#  'Water group',
#  'Plumbing - Accessory Management Drinking Water On Board',
#  'Storage - Waterproof Can - Bag - Pouch - Cover',
#  'Drinking Water Took - Reservoir Gauge',
#  'Siege - driving console - pilotage',
#  'Cordage accessory - Storage - Cording - Trust - Ball',
#  'Mooring',
#  'Multi-purpose boat rope',
#  'Hardware - Listen',
#  'Scale - Matte Chair',
#  'Sandow - Tensioner - Extender - Ferlette',
#  'WIRING',
#  'Voltage converter',
#  'Bridge Lighting - Bridge Projector',
#  'INSIDE LIGHTING',
#  'Navigation light',
#  'Electricity tools',
#  'Boat jack - boat switch',
#  'Energy Production On Board - Eolien - Solar - Hydrogenerur',
#  'Boat Electrical Table',
#  'Antifouling',
#  'Boat Coated - Boat Resin - Gelcoat Boat - Renovator Boat',
#  'Boat repair kit',
#  'Boat sealant',
#  'Engine Cleaning - Engine Maintenance',
#  'Cleaning Bridge - Cleaning Bridge',
#  'Lifting Tool - Lifting Accessory',
#  'Tools - Border Tool',
#  'Primary boat - boat underlay',
#  'Marine hardware',
#  'Boat antialapant',
#  ...]

# %% [markdown]
# ###  Save the translated category level3 names and add them also as the new column of the dataframe

# %%
df['translated_category_level3']=translated_category
df.head()
# Out:
#    category_id              category_level1     category_level2  \
# 0   1000021794        ABONNEMENT / SERVICES      CARTE PREPAYEE
# 1   1000012764  AMENAGEMENT URBAIN - VOIRIE  AMENAGEMENT URBAIN
# 2   1000012776  AMENAGEMENT URBAIN - VOIRIE  AMENAGEMENT URBAIN
# 3   1000012768  AMENAGEMENT URBAIN - VOIRIE  AMENAGEMENT URBAIN
# 4   1000012755  AMENAGEMENT URBAIN - VOIRIE        SIGNALETIQUE
#
#                    category_level3         translated_category_level3
# 0        CARTE PREPAYEE MULTIMEDIA           PREPAYEE MULTIMEDIA CARD
# 1                      ABRI FUMEUR                    Smoking shelter
# 2            ABRI VELO - ABRI MOTO  Bike shelter - motorcycle shelter
# 3                   FONTAINE A EAU                     WATER FOUNTAIN
# 4  PANNEAU D'INFORMATION EXTERIEUR         Exterior Information Panel

# %%
#save the dataframe to csv file for later use 
df.to_csv('translated_category_names.csv',index=False)

# %% [markdown]
# ### <b> 2. Translating category_level2 column

# %% [markdown]
# * Here we follow the same procedure as followed above

# %%
#store all the category names in an array
arr=list(df['category_level2'].values)

#strip the names so that spaces are removed at the ends which is causing problem when translating
arr2= [var.strip() for var in arr]

#list to store the translated category names 
translated_sent=[]

#Loop through each category name to translate it and save it to the list
for sent in tqdm(arr2):
    arr2_trans=translator.translate(sent,src='fr',dest='en')
    translated_sent.append(arr2_trans.text)
# Out:
# 100%|██████████| 5270/5270 [1:01:16<00:00,  1.43it/s]

# %%
translated_sent
# Out:
# ['PREPAID CARD',
#  'Urban development',
#  'Urban development',
#  'Urban development',
#  'Signaletic',
#  'ROAD SIGN',
#  'ROAD SIGN',
#  'ROAD SIGN',
#  'Road',
#  'Road',
#  'Meal accessory',
#  'Meal accessory',
#  'Meal accessory',
#  'Meal accessory',
#  'Meal accessory',
#  'Meal accessory',
#  'Meal accessory',
#  'Meal accessory',
#  'Meal accessory',
#  'Meal accessory',
#  'Meal accessory',
#  'FOOD',
#  'FOOD',
#  'FOOD',
#  'FOOD',
#  'FOOD',
#  'FOOD',
#  'FOOD',
#  'FOOD',
#  'FOOD',
#  'FOOD',
#  'FOOD',
#  'FOOD',
#  'FOOD',
#  'Habitat Technical Development',
#  'Habitat Technical Development',
#  'Habitat Technical Development',
#  'Habitat Technical Development',
#  'Habitat Technical Development',
#  'Habitat Technical Development',
#  'Habitat Technical Development',
#  'Habitat Technical Development',
#  'Tie - Saddlery',
#  'Tie - Saddlery',
#  'Tie - Saddlery',
#  'Tie - Saddlery',
#  'Tie - Saddlery',
#  'Tie - Saddlery',
#  'Tie - Saddlery',
#  'Tie - Saddlery',
#  'Tie - Saddlery',
#  'Tie - Saddlery',
#  'Tie - Saddlery',
#  'Habitat decoration',
#  'Habitat decoration',
#  'Habitat decoration',
#  'Habitat decoration',
#  'Education - Activity',
#  'Education - Activity',
#  'Education - Activity',
#  'Education - Activity',
#  'Education - Activity',
#  'Education - Activity',
#  'Education - Activity',
#  'Education - Activity',
#  'Education - Activity',
#  'Habitat - Sleeping',
#  'Habitat - Sleeping',
#  'Habitat - Sleeping',
#  'Habitat - Sleeping',
#  'Habitat - Sleeping',
#  'Habitat - Sleeping',
#  'Habitat - Sleeping',
#  'Habitat - Sleeping',
#  'Habitat - Sleeping',
#  'Habitat - Sleeping',
#  'Habitat - Sleeping',
#  'Habitat - Sleeping',
#  'Habitat - Sleeping',
#  'Habitat - Sleeping',
#  'Habitat - Sleeping',
#  'Habitat - Sleeping',
#  'Habitat - Sleeping',
#  'Habitat - Sleeping',
#  'Hygiene LITIERE DEJECTIONS',
#  'Hygiene LITIERE DEJECTIONS',
#  'Hygiene LITIERE DEJECTIONS',
#  'Hygiene LITIERE DEJECTIONS',
#  'Hygiene LITIERE DEJECTIONS',
#  'Hygiene LITIERE DEJECTIONS',
#  'Hygiene LITIERE DEJECTIONS',
#  'Hygiene LITIERE DEJECTIONS',
#  'Hygiene LITIERE DEJECTIONS',
#  'Hygiene LITIERE DEJECTIONS',
#  'Hygiene LITIERE DEJECTIONS',
#  'Hygiene LITIERE DEJECTIONS',
#  'TOY',
#  'TOY',
#  'TOY',
#  'TOY',
#  'TOY',
#  'TOY',
#  'TOY',
#  'TOY',
#  'TOY',
#  'TOY',
#  'TOY',
#  'TOY',
#  'Grooming material',
#  'Grooming material',
#  'Grooming material',
#  'Grooming material',
#  'Grooming material',
#  'Grooming material',
#  'Grooming material',
#  'Grooming material',
#  'Grooming material',
#  'Grooming material',
#  'Grooming material',
#  'Grooming material',
#  'Grooming material',
#  'Kindergarten - Breeding',
#  'Kindergarten - Breeding',
#  'Kindergarten - Breeding',
#  'Kindergarten - Breeding',
#  'Care product - Hygiene',
#  'Care product - Hygiene',
#  'Care product - Hygiene',
#  'Care product - Hygiene',
#  'Care product - Hygiene',
#  'Care product - Hygiene',
#  'Care product - Hygiene',
#  'Care product - Hygiene',
#  'Care product - Hygiene',
#  'Care product - Hygiene',
#  'Care product - Hygiene',
#  'SECURITY - PROTECTION',
#  'SECURITY - PROTECTION',
#  'SECURITY - PROTECTION',
#  'SECURITY - PROTECTION',
#  'SECURITY - PROTECTION',
#  'SECURITY - PROTECTION',
#  'SECURITY - PROTECTION',
#  'Transportation - Move - Walk',
#  'Transportation - Move - Walk',
#  'Transportation - Move - Walk',
#  'Transportation - Move - Walk',
#  'Transportation - Move - Walk',
#  'Transportation - Move - Walk',
#  'Transportation - Move - Walk',
#  'Clothing - Accessory',
#  'Clothing - Accessory',
#  'Clothing - Accessory',
#  'Clothing - Accessory',
#  'Clothing - Accessory',
#  'Clothing - Accessory',
#  'Clothing - Accessory',
#  'Clothing - Accessory',
#  'Clothing - Accessory',
#  'Clothing - Accessory',
#  'Clothing - Accessory',
#  'Clothing - Accessory',
#  'Clothing - Accessory',
#  'Clothing - Accessory',
#  'Clothing - Accessory',
#  'Clothing - Accessory',
#  'Clothing - Accessory',
#  'Clothing - Accessory',
#  'Tools of the beekeeper',
#  'Cooking accessory',
#  'Cooking accessory',
#  'Cooking accessory',
#  'Cooking accessory',
#  'Cooking accessory',
#  'Cooking accessory',
#  'Cooking accessory',
#  'Cooking accessory',
#  'Cooking accessory',
#  'Cooking accessory',
#  'Cooking accessory',
#  'Cooking accessory',
#  'Cooking accessory',
#  'Cooking accessory',
#  'Cooking accessory',
#  'Cooking accessory',
#  'Cooking accessory',
#  'Cooking accessory',
#  'Cooking accessory',
#  'Cooking accessory',
#  'Cooking accessory',
#  'Cooking accessory',
#  'Cooking accessory',
#  'Cooking accessory',
#  'Cooking accessory',
#  'Cooking accessory',
#  'Food preservation',
#  'Food preservation',
#  'Food preservation',
#  'Food preservation',
#  'Food preservation',
#  'Food preservation',
#  'Food preservation',
#  'Food preservation',
#  'Food preservation',
#  'Food preservation',
#  'Food preservation',
#  'Food preservation',
#  'Cooking food',
#  'Cooking food',
#  'Cooking food',
#  'Cooking food',
#  'Cooking food',
#  'Cooking food',
#  'Cooking food',
#  'Cooking food',
#  'Cooking food',
#  'Cooking food',
#  'Cooking food',
#  'Cooking food',
#  'Cooking food',
#  'Cooking food',
#  'Cooking food',
#  'Cooking food',
#  'Cooking food',
#  'Cooking food',
#  'Cooking food',
#  'Cooking food',
#  'Cooking food',
#  'Cooking food',
#  'Cooking food',
#  'Cooking food',
#  'Cooking food',
#  'Cooking food',
#  'Cooking food',
#  'Cooking food',
#  'Cutout of food',
#  'Cutout of food',
#  'Cutout of food',
#  'Cutout of food',
#  'Cutout of food',
#  'Cutout of food',
#  'Cutout of food',
#  'Cutout of food',
#  'Cutout of food',
#  'Cutout of food',
#  'Cutout of food',
#  'Cutout of food',
#  'Cutout of food',
#  'Cutout of food',
#  'Nomadic meal',
#  'Nomadic meal',
#  'Nomadic meal',
#  'Aperive Service - Oenology',
#  'Aperive Service - Oenology',
#  'Aperive Service - Oenology',
#  'Aperive Service - Oenology',
#  'Aperive Service - Oenology',
#  'Aperive Service - Oenology',
#  'Aperive Service - Oenology',
#  'Aperive Service - Oenology',
#  'Aperive Service - Oenology',
#  'Aperive Service - Oenology',
#  'Aperive Service - Oenology',
#  'Aperive Service - Oenology',
#  'Aperive Service - Oenology',
#  'Aperive Service - Oenology',
#  'Aperive Service - Oenology',
#  'Aperive Service - Oenology',
#  'Aperive Service - Oenology',
#  'Aperive Service - Oenology',
#  'Aperive Service - Oenology',
#  'Aperive Service - Oenology',
#  'TABLE SERVICE',
#  'TABLE SERVICE',
#  'TABLE SERVICE',
#  'TABLE SERVICE',
#  'TABLE SERVICE',
#  'TABLE SERVICE',
#  'TABLE SERVICE',
#  'TABLE SERVICE',
#  'TABLE SERVICE',
#  'TABLE SERVICE',
#  'TABLE SERVICE',
#  'TABLE SERVICE',
#  'TABLE SERVICE',
#  'TABLE SERVICE',
#  'TABLE SERVICE',
#  'TABLE SERVICE',
#  'TABLE SERVICE',
#  'TABLE SERVICE',
#  'TABLE SERVICE',
#  'TABLE SERVICE',
#  'TABLE SERVICE',
#  'TABLE SERVICE',
#  'TABLE SERVICE',
#  'TABLE SERVICE',
#  'TABLE SERVICE',
#  'TABLE SERVICE',
#  'TABLE SERVICE',
#  'TABLE SERVICE',
#  'TABLE SERVICE',
#  'TABLE SERVICE',
#  'TABLE SERVICE',
#  'TABLE SERVICE',
#  'TABLE SERVICE',
#  'TABLE SERVICE',
#  'TABLE SERVICE',
#  'TABLE SERVICE',
#  'TABLE SERVICE',
#  'TABLE SERVICE',
#  'TABLE SERVICE',
#  'TABLE SERVICE',
#  'TABLE SERVICE',
#  'TABLE SERVICE',
#  'TABLE SERVICE',
#  'Breakfast service',
#  'Breakfast service',
#  'Breakfast service',
#  'Breakfast service',
#  'Breakfast service',
#  'Breakfast service',
#  'Breakfast service',
#  'Breakfast service',
#  'Breakfast service',
#  'Breakfast service',
#  'COOKING TOOLS',
#  'COOKING TOOLS',
#  'COOKING TOOLS',
#  'COOKING TOOLS',
#  'COOKING TOOLS',
#  'COOKING TOOLS',
#  'COOKING TOOLS',
#  'COOKING TOOLS',
#  'COOKING TOOLS',
#  'COOKING TOOLS',
#  'COOKING TOOLS',
#  'COOKING TOOLS',
#  'COOKING TOOLS',
#  'COOKING TOOLS',
#  'COOKING TOOLS',
#  'COOKING TOOLS',
#  'COOKING TOOLS',
#  'COOKING TOOLS',
#  'COOKING TOOLS',
#  'COOKING TOOLS',
#  'COOKING TOOLS',
#  'COOKING TOOLS',
#  'COOKING TOOLS',
#  'COOKING TOOLS',
#  'COOKING TOOLS',
#  'COOKING TOOLS',
#  'COOKING TOOLS',
#  'COOKING TOOLS',
#  'COOKING TOOLS',
#  'COOKING TOOLS',
#  'COOKING TOOLS',
#  'COOKING TOOLS',
#  'COOKING TOOLS',
#  'COOKING TOOLS',
#  'COOKING TOOLS',
#  'COOKING TOOLS',
#  'COOKING TOOLS',
#  'COOKING TOOLS',
#  'COOKING TOOLS',
#  'COOKING TOOLS',
#  'COOKING TOOLS',
#  'COOKING TOOLS',
#  'COOKING TOOLS',
#  'COOKING TOOLS',
#  'Weighing utensils - Measurement',
#  'Weighing utensils - Measurement',
#  'Weighing utensils - Measurement',
#  'Weighing utensils - Measurement',
#  'Weighing utensils - Measurement',
#  'Patisserie utensils',
#  'Patisserie utensils',
#  'Patisserie utensils',
#  'Patisserie utensils',
#  'Patisserie utensils',
#  'Patisserie utensils',
#  'Patisserie utensils',
#  'Patisserie utensils',
#  'Patisserie utensils',
#  'Patisserie utensils',
#  'Patisserie utensils',
#  'Patisserie utensils',
#  'Patisserie utensils',
#  'Patisserie utensils',
#  'Patisserie utensils',
#  'Patisserie utensils',
#  'Patisserie utensils',
#  'Patisserie utensils',
#  'Patisserie utensils',
#  'Patisserie utensils',
#  'Patisserie utensils',
#  'Patisserie utensils',
#  'Patisserie utensils',
#  'DISPOSABLE DISHES',
#  'DISPOSABLE DISHES',
#  'DISPOSABLE DISHES',
#  'DISPOSABLE DISHES',
#  'DISPOSABLE DISHES',
#  'DISPOSABLE DISHES',
#  'DISPOSABLE DISHES',
#  'DISPOSABLE DISHES',
#  'DISPOSABLE DISHES',
#  'Chicha - Narguile',
#  'Chicha - Narguile',
#  'Chicha - Narguile',
#  'Chicha - Narguile',
#  'Chicha - Narguile',
#  'Chicha - Narguile',
#  'Chicha - Narguile',
#  'Chicha - Narguile',
#  'Chicha - Narguile',
#  'Chicha - Narguile',
#  'CIGAR',
#  'CIGAR',
#  'CIGAR',
#  'CIGAR',
#  'CIGARETTE',
#  'CIGARETTE',
#  'CIGARETTE',
#  'CIGARETTE',
#  'CIGARETTE',
#  'CIGARETTE',
#  'CIGARETTE',
#  'CIGARETTE',
#  'CIGARETTE',
#  'CIGARETTE',
#  'CIGARETTE',
#  'ELECTRONIC CIGARETTE',
#  'ELECTRONIC CIGARETTE',
#  'ELECTRONIC CIGARETTE',
#  'ELECTRONIC CIGARETTE',
#  'ELECTRONIC CIGARETTE',
#  'ELECTRONIC CIGARETTE',
#  'ELECTRONIC CIGARETTE',
#  'ELECTRONIC CIGARETTE',
#  'ELECTRONIC CIGARETTE',
#  'ELECTRONIC CIGARETTE',
#  'ELECTRONIC CIGARETTE',
#  'ELECTRONIC CIGARETTE',
#  'ELECTRONIC CIGARETTE',
#  'ELECTRONIC CIGARETTE',
#  'SMOKING PIPE',
#  'SMOKING PIPE',
#  'SMOKING PIPE',
#  'SMOKING PIPE',
#  'SMOKING PIPE',
#  'SPRAY',
#  'SPRAY',
#  'SPRAY',
#  'SPRAY',
#  'DRIVING HELP - SECURITY',
#  'DRIVING HELP - SECURITY',
#  'DRIVING HELP - SECURITY',
#  'DRIVING HELP - SECURITY',
#  'DRIVING HELP - SECURITY',
#  'DRIVING HELP - SECURITY',
#  'DRIVING HELP - SECURITY',
#  'DRIVING HELP - SECURITY',
#  'DRIVING HELP - SECURITY',
#  'DRIVING HELP - SECURITY',
#  'DRIVING HELP - SECURITY',
#  'DRIVING HELP - SECURITY',
#  'DRIVING HELP - SECURITY',
#  'DRIVING HELP - SECURITY',
#  'DRIVING HELP - SECURITY',
#  'DRIVING HELP - SECURITY',
#  'DRIVING HELP - SECURITY',
#  'DRIVING HELP - SECURITY',
#  'DRIVING HELP - SECURITY',
#  'DRIVING HELP - SECURITY',
#  'DRIVING HELP - SECURITY',
#  'DRIVING HELP - SECURITY',
#  'DRIVING HELP - SECURITY',
#  'Luggage Storage',
#  'Luggage Storage',
#  'Luggage Storage',
#  'Luggage Storage',
#  'Luggage Storage',
#  'Luggage Storage',
#  'Luggage Storage',
#  'Luggage Storage',
#  'Luggage Storage',
#  'CONFORT CONDUCTOR AND PASSENGER',
#  'CONFORT CONDUCTOR AND PASSENGER',
#  'CONFORT CONDUCTOR AND PASSENGER',
#  'CONFORT CONDUCTOR AND PASSENGER',
#  'CONFORT CONDUCTOR AND PASSENGER',
#  'CONFORT CONDUCTOR AND PASSENGER',
#  'CONFORT CONDUCTOR AND PASSENGER',
#  'CONFORT CONDUCTOR AND PASSENGER',
#  'CONFORT CONDUCTOR AND PASSENGER',
#  'CONFORT CONDUCTOR AND PASSENGER',
#  'CONFORT CONDUCTOR AND PASSENGER',
#  'CONFORT CONDUCTOR AND PASSENGER',
#  'CONFORT CONDUCTOR AND PASSENGER',
#  'CONFORT CONDUCTOR AND PASSENGER',
#  'CONFORT CONDUCTOR AND PASSENGER',
#  'CONFORT CONDUCTOR AND PASSENGER',
#  'CONFORT CONDUCTOR AND PASSENGER',
#  'CONFORT CONDUCTOR AND PASSENGER',
#  'CONFORT CONDUCTOR AND PASSENGER',
#  'CONFORT CONDUCTOR AND PASSENGER',
#  'CONFORT CONDUCTOR AND PASSENGER',
#  'CONFORT CONDUCTOR AND PASSENGER',
#  'CONFORT CONDUCTOR AND PASSENGER',
#  'CONFORT CONDUCTOR AND PASSENGER',
#  'CONFORT CONDUCTOR AND PASSENGER',
#  'CONFORT CONDUCTOR AND PASSENGER',
#  'CONFORT CONDUCTOR AND PASSENGER',
#  'CONFORT CONDUCTOR AND PASSENGER',
#  'CONFORT CONDUCTOR AND PASSENGER',
#  'CONFORT CONDUCTOR AND PASSENGER',
#  'CONFORT CONDUCTOR AND PASSENGER',
#  'CONFORT CONDUCTOR AND PASSENGER',
#  'CONFORT CONDUCTOR AND PASSENGER',
#  'CONFORT CONDUCTOR AND PASSENGER',
#  'CONFORT CONDUCTOR AND PASSENGER',
#  'CONFORT CONDUCTOR AND PASSENGER',
#  'CONFORT CONDUCTOR AND PASSENGER',
#  'CONFORT CONDUCTOR AND PASSENGER',
#  'CONFORT CONDUCTOR AND PASSENGER',
#  'CONFORT CONDUCTOR AND PASSENGER',
#  'CONFORT CONDUCTOR AND PASSENGER',
#  'CONFORT CONDUCTOR AND PASSENGER',
#  'CONFORT CONDUCTOR AND PASSENGER',
#  'CONFORT CONDUCTOR AND PASSENGER',
#  'CONFORT CONDUCTOR AND PASSENGER',
#  'Pilot equipment',
#  'Pilot equipment',
#  'Pilot equipment',
#  'Pilot equipment',
#  'Pilot equipment',
#  'Pilot equipment',
#  'Pilot equipment',
#  'Pilot equipment',
#  'Pilot equipment',
#  'Pilot equipment',
#  'Pilot equipment',
#  'Pilot equipment',
#  'Pilot equipment',
#  'Pilot equipment',
#  'Pilot equipment',
#  'Pilot equipment',
#  'Pilot equipment',
#  'Pilot equipment',
#  'Pilot equipment',
#  'Pilot equipment',
#  'Mobile home - Interior development',
#  'Mobile home - Interior development',
#  'Mobile home - Interior development',
#  'Mobile home - Interior development',
#  'Mobile home - Interior development',
#  'Mobile home - Interior development',
#  'Mobile home - Interior development',
#  'Mobile home - Interior development',
#  'Mobile home - Interior development',
#  'Mobile home - Interior development',
#  'Mobile home - Interior development',
#  'Mobile home - Interior development',
#  'Mobile home - Interior development',
#  'Mobile home - Interior development',
#  'Cleaning - Liquid Maintenance',
#  'Cleaning - Liquid Maintenance',
#  'Cleaning - Liquid Maintenance',
#  'Cleaning - Liquid Maintenance',
#  'Cleaning - Liquid Maintenance',
#  'Cleaning - Liquid Maintenance',
#  'Cleaning - Liquid Maintenance',
#  'Cleaning - Liquid Maintenance',
#  'Cleaning - Liquid Maintenance',
#  'Cleaning - Liquid Maintenance',
#  'Cleaning - Liquid Maintenance',
#  'Cleaning - Liquid Maintenance',
#  'Cleaning - Liquid Maintenance',
#  'Cleaning - Liquid Maintenance',
#  'Cleaning - Liquid Maintenance',
#  'Cleaning - Liquid Maintenance',
#  'Cleaning - Liquid Maintenance',
#  'Cleaning - Liquid Maintenance',
#  'Cleaning - Liquid Maintenance',
#  'Cleaning - Liquid Maintenance',
#  'Cleaning - Liquid Maintenance',
#  'Cleaning - Liquid Maintenance',
#  'Cleaning - Liquid Maintenance',
#  'Cleaning - Liquid Maintenance',
#  'Cleaning - Liquid Maintenance',
#  'Cleaning - Liquid Maintenance',
#  'Cleaning - Liquid Maintenance',
#  'Cleaning - Liquid Maintenance',
#  'Cleaning - Liquid Maintenance',
#  'Tooling',
#  'Tooling',
#  'Tooling',
#  'Tooling',
#  'Tooling',
#  'Tooling',
#  'Tooling',
#  'Tooling',
#  'Tooling',
#  'Tooling',
#  'Tooling',
#  'Tooling',
#  'Tooling',
#  'Tooling',
#  'Tooling',
#  'Tooling',
#  'Tooling',
#  'Tooling',
#  'Tooling',
#  'Tooling',
#  'Tooling',
#  'Tooling',
#  'Tooling',
#  'Tooling',
#  'Tooling',
#  'Tooling',
#  'Tooling',
#  'Tooling',
#  'Tooling',
#  'Tooling',
#  'Tooling',
#  'Tooling',
#  'Tooling',
#  'Tooling',
#  'Tooling',
#  'Tooling',
#  'Tooling',
#  'Tooling',
#  'Tooling',
#  'Tooling',
#  'Tooling',
#  'Tooling',
#  'Tooling',
#  'Tooling',
#  'Tooling',
#  'Tooling',
#  'Tooling',
#  'Tooling',
#  'Tooling',
#  'Tooling',
#  'Tooling',
#  'Tooling',
#  'Tooling',
#  'Tooling',
#  'Tooling',
#  'Tooling',
#  'Tooling',
#  'Tooling',
#  'Tooling',
#  'Tooling',
#  'Tooling',
#  'Tooling',
#  'Tooling',
#  'Tooling',
#  'Tooling',
#  'Tooling',
#  'Tooling',
#  'Tooling',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'ROOMS',
#  'Tires',
#  'Tires',
#  'Tires',
#  'Tires',
#  'Tires',
#  'Tires',
#  'Portage - Towing',
#  'Portage - Towing',
#  'Portage - Towing',
#  'Portage - Towing',
#  'Portage - Towing',
#  'Portage - Towing',
#  'Portage - Towing',
#  'Portage - Towing',
#  'Portage - Towing',
#  'Portage - Towing',
#  'Portage - Towing',
#  'Portage - Towing',
#  'Portage - Towing',
#  'Portage - Towing',
#  'Portage - Towing',
#  'Portage - Towing',
#  'Portage - Towing',
#  'Portage - Towing',
#  'Portage - Towing',
#  'Portage - Towing',
#  'Portage - Towing',
#  'Portage - Towing',
#  'Portage - Towing',
#  'Portage - Towing',
#  'Portage - Towing',
#  'Portage - Towing',
#  'Portage - Towing',
#  'VEHICLE',
#  'VEHICLE',
#  'VEHICLE',
#  'VEHICLE',
#  'VEHICLE',
#  'VEHICLE',
#  'VEHICLE',
#  'VEHICLE',
#  'VEHICLE',
#  'VEHICLE',
#  'VEHICLE',
#  'VEHICLE',
#  'Luggage accessories',
#  'Luggage accessories',
#  'Luggage accessories',
#  'Luggage accessories',
#  'Luggage accessories',
#  'Luggage accessories',
#  'Luggage accessories',
#  'Luggage accessories',
#  'Luggage accessories',
#  'Luggage accessories',
#  'Luggage accessories',
#  'Luggage accessories',
#  'Luggage accessories',
#  'Luggage accessories',
#  'Luggage accessories',
#  'Luggage accessories',
#  'Luggage accessories',
#  'Luggage accessories',
#  'Luggage accessories',
#  'Luggage accessories',
#  'Luggage accessories',
#  'Luggage accessories',
#  'Luggage',
#  'Luggage',
#  'Luggage',
#  'Luggage',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Leather goods',
#  'Leather goods',
#  'Leather goods',
#  'Leather goods',
#  'Leather goods',
#  'Leather goods',
#  'Leather goods',
#  'Leather goods',
#  'Leather goods',
#  'Leather goods',
#  'Leather goods',
#  'Leather goods',
#  'LITTLE LEATHER SHOP',
#  'LITTLE LEATHER SHOP',
#  'LITTLE LEATHER SHOP',
#  'LITTLE LEATHER SHOP',
#  'LITTLE LEATHER SHOP',
#  'LITTLE LEATHER SHOP',
#  'LITTLE LEATHER SHOP',
#  'LITTLE LEATHER SHOP',
#  'LITTLE LEATHER SHOP',
#  'LITTLE LEATHER SHOP',
#  'LITTLE LEATHER SHOP',
#  'Tidbit',
#  'Tidbit',
#  'Tidbit',
#  'Tidbit',
#  'Tidbit',
#  'Tidbit',
#  'Tidbit',
#  'Tidbit',
#  'Tidbit',
#  'Tidbit',
#  'Tidbit',
#  'Tidbit',
#  'Tidbit',
#  'Appendix - Boat',
#  'MOTORBOAT',
#  'MOTORBOAT',
#  'Comfort on board',
#  'Comfort on board',
#  'Comfort on board',
#  'Comfort on board',
#  'Comfort on board',
#  'Comfort on board',
#  'Comfort on board',
#  'ROPE',
#  'ROPE',
#  'ROPE',
#  'ROPE',
#  'ROPE',
#  'ROPE',
#  'ELECTRICITY',
#  'ELECTRICITY',
#  'ELECTRICITY',
#  'ELECTRICITY',
#  'ELECTRICITY',
#  'ELECTRICITY',
#  'ELECTRICITY',
#  'ELECTRICITY',
#  'ELECTRICITY',
#  'INTERVIEW',
#  'INTERVIEW',
#  'INTERVIEW',
#  'INTERVIEW',
#  'INTERVIEW',
#  'INTERVIEW',
#  'INTERVIEW',
#  'INTERVIEW',
#  'INTERVIEW',
#  'INTERVIEW',
#  'INTERVIEW',
#  ...]

# %% [markdown]
# Save the translated category level2 also to the dataframe as a new column

# %%
df['translated_category_level2']=translated_sent

#save the dataframe to the disk for later use
df.to_csv('translated_category_names.csv',index=False)
df.head()
# Out:
#    category_id              category_level1     category_level2  \
# 0   1000021794        ABONNEMENT / SERVICES      CARTE PREPAYEE
# 1   1000012764  AMENAGEMENT URBAIN - VOIRIE  AMENAGEMENT URBAIN
# 2   1000012776  AMENAGEMENT URBAIN - VOIRIE  AMENAGEMENT URBAIN
# 3   1000012768  AMENAGEMENT URBAIN - VOIRIE  AMENAGEMENT URBAIN
# 4   1000012755  AMENAGEMENT URBAIN - VOIRIE        SIGNALETIQUE
#
#                    category_level3         translated_category_level3  \
# 0        CARTE PREPAYEE MULTIMEDIA           PREPAYEE MULTIMEDIA CARD
# 1                      ABRI FUMEUR                    Smoking shelter
# 2            ABRI VELO - ABRI MOTO  Bike shelter - motorcycle shelter
# 3                   FONTAINE A EAU                     WATER FOUNTAIN
# 4  PANNEAU D'INFORMATION EXTERIEUR         Exterior Information Panel
#
#   translated_category_level2
# 0               PREPAID CARD
# 1          Urban development
# 2          Urban development
# 3          Urban development
# 4                 Signaletic

# %% [markdown]
# ### <b> 3. Translating category_level1 column </b>
# * Here also we follow the same procedure as above

# %%
#store all the category names in an array
arr=list(df['category_level1'].values)

#strip the names so that spaces are removed at the ends which is causing problem when translating
arr2= [var.strip() for var in arr]

#list to store the translated category names 
translated_sent=[]

#Loop through each category name to translate it and save it to the list
for sent in tqdm(arr2):
    arr2_trans=translator.translate(sent,src='fr',dest='en')
    translated_sent.append(arr2_trans.text)
# Out:
# 100%|██████████| 5270/5270 [59:34<00:00,  1.47it/s]

# %%
translated_sent
# Out:
# ['Subscription / Services',
#  'Urban Processing - Roads',
#  'Urban Processing - Roads',
#  'Urban Processing - Roads',
#  'Urban Processing - Roads',
#  'Urban Processing - Roads',
#  'Urban Processing - Roads',
#  'Urban Processing - Roads',
#  'Urban Processing - Roads',
#  'Urban Processing - Roads',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'PET SHOP',
#  'BEEKEEPING',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  'Art of the Table - Culinary Articles',
#  "Smoker's Items",
#  "Smoker's Items",
#  "Smoker's Items",
#  "Smoker's Items",
#  "Smoker's Items",
#  "Smoker's Items",
#  "Smoker's Items",
#  "Smoker's Items",
#  "Smoker's Items",
#  "Smoker's Items",
#  "Smoker's Items",
#  "Smoker's Items",
#  "Smoker's Items",
#  "Smoker's Items",
#  "Smoker's Items",
#  "Smoker's Items",
#  "Smoker's Items",
#  "Smoker's Items",
#  "Smoker's Items",
#  "Smoker's Items",
#  "Smoker's Items",
#  "Smoker's Items",
#  "Smoker's Items",
#  "Smoker's Items",
#  "Smoker's Items",
#  "Smoker's Items",
#  "Smoker's Items",
#  "Smoker's Items",
#  "Smoker's Items",
#  "Smoker's Items",
#  "Smoker's Items",
#  "Smoker's Items",
#  "Smoker's Items",
#  "Smoker's Items",
#  "Smoker's Items",
#  "Smoker's Items",
#  "Smoker's Items",
#  "Smoker's Items",
#  "Smoker's Items",
#  "Smoker's Items",
#  "Smoker's Items",
#  "Smoker's Items",
#  "Smoker's Items",
#  "Smoker's Items",
#  "Smoker's Items",
#  "Smoker's Items",
#  "Smoker's Items",
#  "Smoker's Items",
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'AUTO MOTO',
#  'Luggage storage',
#  'Luggage storage',
#  'Luggage storage',
#  'Luggage storage',
#  'Luggage storage',
#  'Luggage storage',
#  'Luggage storage',
#  'Luggage storage',
#  'Luggage storage',
#  'Luggage storage',
#  'Luggage storage',
#  'Luggage storage',
#  'Luggage storage',
#  'Luggage storage',
#  'Luggage storage',
#  'Luggage storage',
#  'Luggage storage',
#  'Luggage storage',
#  'Luggage storage',
#  'Luggage storage',
#  'Luggage storage',
#  'Luggage storage',
#  'Luggage storage',
#  'Luggage storage',
#  'Luggage storage',
#  'Luggage storage',
#  'Luggage storage',
#  'Luggage storage',
#  'Luggage storage',
#  'Luggage storage',
#  'Luggage storage',
#  'Luggage storage',
#  'Luggage storage',
#  'Luggage storage',
#  'Luggage storage',
#  'Luggage storage',
#  'Luggage storage',
#  'Luggage storage',
#  'Luggage storage',
#  'Luggage storage',
#  'Luggage storage',
#  'Luggage storage',
#  'Luggage storage',
#  'Luggage storage',
#  'Luggage storage',
#  'Luggage storage',
#  'Luggage storage',
#  'Luggage storage',
#  'Luggage storage',
#  'Luggage storage',
#  'Luggage storage',
#  'Luggage storage',
#  'Luggage storage',
#  'Luggage storage',
#  'Luggage storage',
#  'Luggage storage',
#  'Luggage storage',
#  'Motor Boat - Sailboat',
#  'Motor Boat - Sailboat',
#  'Motor Boat - Sailboat',
#  'Motor Boat - Sailboat',
#  'Motor Boat - Sailboat',
#  'Motor Boat - Sailboat',
#  'Motor Boat - Sailboat',
#  'Motor Boat - Sailboat',
#  'Motor Boat - Sailboat',
#  'Motor Boat - Sailboat',
#  'Motor Boat - Sailboat',
#  'Motor Boat - Sailboat',
#  'Motor Boat - Sailboat',
#  'Motor Boat - Sailboat',
#  'Motor Boat - Sailboat',
#  'Motor Boat - Sailboat',
#  'Motor Boat - Sailboat',
#  'Motor Boat - Sailboat',
#  'Motor Boat - Sailboat',
#  'Motor Boat - Sailboat',
#  'Motor Boat - Sailboat',
#  'Motor Boat - Sailboat',
#  'Motor Boat - Sailboat',
#  'Motor Boat - Sailboat',
#  'Motor Boat - Sailboat',
#  'Motor Boat - Sailboat',
#  'Motor Boat - Sailboat',
#  'Motor Boat - Sailboat',
#  'Motor Boat - Sailboat',
#  'Motor Boat - Sailboat',
#  'Motor Boat - Sailboat',
#  'Motor Boat - Sailboat',
#  'Motor Boat - Sailboat',
#  'Motor Boat - Sailboat',
#  'Motor Boat - Sailboat',
#  'Motor Boat - Sailboat',
#  'Motor Boat - Sailboat',
#  'Motor Boat - Sailboat',
#  'Motor Boat - Sailboat',
#  'Motor Boat - Sailboat',
#  'Motor Boat - Sailboat',
#  'Motor Boat - Sailboat',
#  'Motor Boat - Sailboat',
#  'Motor Boat - Sailboat',
#  'Motor Boat - Sailboat',
#  'Motor Boat - Sailboat',
#  'Motor Boat - Sailboat',
#  'Motor Boat - Sailboat',
#  'Motor Boat - Sailboat',
#  ...]

# %% [markdown]
# Save the translated category level2 also to the dataframe as a new column

# %%
df['translated_category_level1'] = translated_sent

#save the dataframe to the disk for later use
df.to_csv('translated_category_names.csv',index=False)
df.head()
# Out:
#    category_id              category_level1     category_level2  \
# 0   1000021794        ABONNEMENT / SERVICES      CARTE PREPAYEE
# 1   1000012764  AMENAGEMENT URBAIN - VOIRIE  AMENAGEMENT URBAIN
# 2   1000012776  AMENAGEMENT URBAIN - VOIRIE  AMENAGEMENT URBAIN
# 3   1000012768  AMENAGEMENT URBAIN - VOIRIE  AMENAGEMENT URBAIN
# 4   1000012755  AMENAGEMENT URBAIN - VOIRIE        SIGNALETIQUE
#
#                    category_level3         translated_category_level3  \
# 0        CARTE PREPAYEE MULTIMEDIA            PREPAID MULTIMEDIA CARD
# 1                      ABRI FUMEUR                    Smoking shelter
# 2            ABRI VELO - ABRI MOTO  Bike shelter - motorcycle shelter
# 3                   FONTAINE A EAU                     WATER FOUNTAIN
# 4  PANNEAU D'INFORMATION EXTERIEUR         Exterior Information Panel
#
#   translated_category_level2 translated_category_level1
# 0               PREPAID CARD    Subscription / Services
# 1          Urban development   Urban Processing - Roads
# 2          Urban development   Urban Processing - Roads
# 3          Urban development   Urban Processing - Roads
# 4                 Signaletic   Urban Processing - Roads
